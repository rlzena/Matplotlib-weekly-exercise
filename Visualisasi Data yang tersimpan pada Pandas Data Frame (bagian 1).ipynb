# %% [markdown]
# Visualisasi Data yang tersimpan pada Pandas Data Frame (bagian 1)
#
# Link youtube : https://www.youtube.com/watch?v=a--mGiWlj1s&authuser=0

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

print(matplotlib.__version__)
print(pd.__version__)
# Out:
# 3.7.2
# 2.0.3

# %%
df = pd.DataFrame({
    'nama': ['cecep', 'karti', 'bejo', 'tejo', 'asep', 'wati', 'amat'],
    'usia': [23, 78, 22, 19, 45, 33, 20],
    'gender': ['L', 'P', 'L', 'L', 'L', 'P', 'L'],
    'propinsi':
    ['jabar', 'jatim', 'jabar', 'jatim', 'jabar', 'jateng', 'jateng'],
    'n_anak': [2, 0, 0, 2, 3, 0, 4],
    'n_pets': [5, 1, 0, 5, 2, 2, 3]
})

df
# Out:
#     nama  usia gender propinsi  n_anak  n_pets
# 0  cecep    23      L    jabar       2       5
# 1  karti    78      P    jatim       0       1
# 2   bejo    22      L    jabar       0       0
# 3   tejo    19      L    jatim       2       5
# 4   asep    45      L    jabar       3       2
# 5   wati    33      P   jateng       0       2
# 6   amat    20      L   jateng       4       3

# %%
df.plot(kind='scatter', x='n_anak', y='n_pets', color='red')

plt.title('scatter Plot')
plt.xlabel('Jumlah Anak')
plt.ylabel('Jumlah Pets')
plt.show()

# %%
df[['usia']].plot(kind='hist', bins=[0, 20, 40, 60, 80, 100])

plt.title('Histogram')
plt.xlabel('Usia')
plt.ylabel('Jumlah')
plt.show()

# %%
df.plot(kind='line', x='nama', y='n_anak', color='green')

plt.title('Line Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.plot(kind='line', x='nama', y='n_anak', color='green')
df.plot(kind='line', x='nama', y='n_pets', color='red')

plt.title('Line Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
ax = plt.gca()

df.plot(kind='line', x='nama', y='n_anak', color='green', ax=ax)
df.plot(kind='line', x='nama', y='n_pets', color='red', ax=ax)

plt.title('Line Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.plot(kind='bar', x='nama', y='usia')

plt.title('Bar Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.groupby('propinsi')['nama'].count().plot(kind='bar')

plt.title('Bar Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.groupby(['propinsi', 'gender']).size().unstack().plot(kind='bar', stacked=True)

plt.title('Bar Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.groupby(['gender', 'propinsi']).size().unstack().plot(kind='bar', stacked=True)

plt.title('Bar Plot')
plt.ylabel('Jumlah')
plt.show()
